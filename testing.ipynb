# %%
import pandas as pd

# %%
# temp = pd.read_json("racesfrtest.json")
# temp = pd.read_json("racesfr.json")
temp = pd.read_json("racesTR.json")
# temp = pd.read_json("TR-20251029.json")

# temp = pd.read_json("sailors-latest.json")
# temp = pd.read_json("sailor_data2.json")

# %%
# len(temp["raceID"].unique())
# temp[temp['Team'] == 'Schools']
# temp[temp['Teams'].apply(lambda x: x[0] == '')]
# [t['boatName'] for t in temp[temp['key'] == 'carter-anderson']['Races'].iat[0]]
# races = temp[temp['key'] == 'carter-anderson']['Races'].iat[0]
# [r for r  in races if r['raceID'].split("/")[0] == 'f25' and r['pos'] == 'Skipper']
temp
# Out:
# 474

# %%
test = pd.read_json("racesfrTEST.json")

# %%
test
# Out:
#      Score Div             Sailor               Link                key  \
# 0        1   A  Brian Fitzsimmons  brian-fitzsimmons  brian-fitzsimmons
# 1        6   A  Brian Fitzsimmons  brian-fitzsimmons  brian-fitzsimmons
# 2        1   A  Brian Fitzsimmons  brian-fitzsimmons  brian-fitzsimmons
# 3        3   A  Brian Fitzsimmons  brian-fitzsimmons  brian-fitzsimmons
# 4        1   A  Brian Fitzsimmons  brian-fitzsimmons  brian-fitzsimmons
# ..     ...  ..                ...                ...                ...
# 723     23   B       Khushi Gupta       khushi-gupta       khushi-gupta
# 724     25   B     Delia Stobaugh     delia-stobaugh     delia-stobaugh
# 725     25   B     Delia Stobaugh     delia-stobaugh     delia-stobaugh
# 726     22   B     Delia Stobaugh     delia-stobaugh     delia-stobaugh
# 727     17   B     Delia Stobaugh     delia-stobaugh     delia-stobaugh
#
#     GradYear Position        Partner         Venue              Regatta  \
# 0         26  Skipper  Chas Mitchell  UC San Diego  f24/ucsd-frosh-soph
# 1         26  Skipper  Chas Mitchell  UC San Diego  f24/ucsd-frosh-soph
# 2         26  Skipper  Chas Mitchell  UC San Diego  f24/ucsd-frosh-soph
# 3         26  Skipper  Chas Mitchell  UC San Diego  f24/ucsd-frosh-soph
# 4         26  Skipper  Chas Mitchell  UC San Diego  f24/ucsd-frosh-soph
# ..       ...      ...            ...           ...                  ...
# 723       27     Crew    Felix Zhang  UC San Diego  f24/ucsd-frosh-soph
# 724       27     Crew    Felix Zhang  UC San Diego  f24/ucsd-frosh-soph
# 725       27     Crew    Felix Zhang  UC San Diego  f24/ucsd-frosh-soph
# 726       27     Crew    Felix Zhang  UC San Diego  f24/ucsd-frosh-soph
# 727       27     Crew    Felix Zhang  UC San Diego  f24/ucsd-frosh-soph
#
#          Scoring                  raceID         adjusted_raceID Date  \
# 0    2 Divisions  f24/ucsd-frosh-soph/1A  f24/ucsd-frosh-soph/1A  NaT
# 1    2 Divisions  f24/ucsd-frosh-soph/2A  f24/ucsd-frosh-soph/2A  NaT
# 2    2 Divisions  f24/ucsd-frosh-soph/3A  f24/ucsd-frosh-soph/3A  NaT
# 3    2 Divisions  f24/ucsd-frosh-soph/4A  f24/ucsd-frosh-soph/4A  NaT
# 4    2 Divisions  f24/ucsd-frosh-soph/5A  f24/ucsd-frosh-soph/5A  NaT
# ..           ...                     ...                     ...  ...
# 723  2 Divisions  f24/ucsd-frosh-soph/6B  f24/ucsd-frosh-soph/6B  NaT
# 724  2 Divisions  f24/ucsd-frosh-soph/3B  f24/ucsd-frosh-soph/3B  NaT
# 725  2 Divisions  f24/ucsd-frosh-soph/4B  f24/ucsd-frosh-soph/4B  NaT
# 726  2 Divisions  f24/ucsd-frosh-soph/7B  f24/ucsd-frosh-soph/7B  NaT
# 727  2 Divisions  f24/ucsd-frosh-soph/8B  f24/ucsd-frosh-soph/8B  NaT
#
#      raceNum            Team        Teamlink Boat    PartnerLink  \
# 0          1   UC Santa Cruz   uc-santa-cruz   FJ  chas-mitchell
# 1          2   UC Santa Cruz   uc-santa-cruz   FJ  chas-mitchell
# 2          3   UC Santa Cruz   uc-santa-cruz   FJ  chas-mitchell
# 3          4   UC Santa Cruz   uc-santa-cruz   FJ  chas-mitchell
# 4          5   UC Santa Cruz   uc-santa-cruz   FJ  chas-mitchell
# ..       ...             ...             ...  ...            ...
# 723        6  UC Los Angeles  uc-los-angeles   FJ    felix-zhang
# 724        3  UC Los Angeles  uc-los-angeles   FJ    felix-zhang
# 725        4  UC Los Angeles  uc-los-angeles   FJ    felix-zhang
# 726        7  UC Los Angeles  uc-los-angeles   FJ    felix-zhang
# 727        8  UC Los Angeles  uc-los-angeles   FJ    felix-zhang
#
#         partnerKey
# 0    chas-mitchell
# 1    chas-mitchell
# 2    chas-mitchell
# 3    chas-mitchell
# 4    chas-mitchell
# ..             ...
# 723    felix-zhang
# 724    felix-zhang
# 725    felix-zhang
# 726    felix-zhang
# 727    felix-zhang
#
# [728 rows x 20 columns]
