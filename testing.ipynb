# %%
import pandas as pd

# %%
# df = pd.read_parquet("racesTR.parquet")
df = pd.read_parquet("racesfrtest.parquet")
# df = df.loc[df['Date'] > '2026-1-1']
df
# Out:
#          Score Div         Sailor           Link                         key  \
# 0          6.0   A    Tyler Sinks        Unknown  Tyler Sinks-Boston College
# 1          5.0   A    Tyler Sinks        Unknown  Tyler Sinks-Boston College
# 2         15.0   A    Tyler Sinks        Unknown  Tyler Sinks-Boston College
# 3          2.0   A    Tyler Sinks        Unknown  Tyler Sinks-Boston College
# 4          8.0   A    Tyler Sinks        Unknown  Tyler Sinks-Boston College
# ...        ...  ..            ...            ...                         ...
# 1463453   10.0   B  Howell Conrad  howell-conrad               howell-conrad
# 1463454    6.0   B  Howell Conrad  howell-conrad               howell-conrad
# 1463455   11.0   B  Howell Conrad  howell-conrad               howell-conrad
# 1463456   11.0   B  Howell Conrad  howell-conrad               howell-conrad
# 1463457    7.0   B  Howell Conrad  howell-conrad               howell-conrad
#
# ...
