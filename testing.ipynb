# %%
import pandas as pd

# %%
# df = pd.read_parquet("racesTR.parquet")
df = pd.read_json("racesTR.json")
df = df.loc[df['date'] > '2026-1-1']
df
# Out:
#                  raceID         regatta  raceNum    round       date  \
# 22630  s26/q1-regatta/1  s26/q1-regatta        1  Round 1 2026-01-31
# 22631  s26/q1-regatta/2  s26/q1-regatta        2  Round 1 2026-01-31
# 22632  s26/q1-regatta/3  s26/q1-regatta        3  Round 1 2026-01-31
# 22633  s26/q1-regatta/4  s26/q1-regatta        4  Round 1 2026-01-31
# 22634  s26/q1-regatta/5  s26/q1-regatta        5  Round 1 2026-01-31
# 22635  s26/q1-regatta/6  s26/q1-regatta        6  Round 1 2026-01-31
#
#                                           allSkipperKeys  \
# 22630                                                 []
# 22631  [joe-slipper, adeline-thompson, lewis-forrest,...
# 22632  [elizabeth-cleaves, Logan Downey-Texas, Dennis...
# 22633  [kate-hennig, sofia-pando-2029, korbin-bendele...
# 22634  [elizabeth-cleaves, Logan Downey-Texas, Dennis...
# 22635  [kate-hennig, sofia-pando-2029, korbin-bendele...
#
#                                              allCrewKeys  teamAName  \
# ...
