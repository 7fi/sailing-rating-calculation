# %%
import importlib
import main

people, df_races_full = main.main("../")
# Out:
# Reading from files.
# Setup complete.
# Starting calculations.
# Currently analyzing race 1000/55065 in ('s16/ike-geiger-team-race',), Date:2016-03-19 00:00:00
# Currently analyzing race 2000/55065 in ('s16/oberg',), Date:2016-04-16 00:00:00
# Currently analyzing race 3000/55065 in ('f16/hatch-brown',), Date:2016-09-17 00:00:00
# Currently analyzing race 4000/55065 in ('f16/protest',), Date:2016-10-09 00:00:00
# Currently analyzing race 5000/55065 in ('s17/barnyard-bizzare',), Date:2017-03-04 00:00:00
# Currently analyzing race 6000/55065 in ('s17/admiral-moore-team-race',), Date:2017-03-25 00:00:00
# Currently analyzing race 7000/55065 in ('s17/new-england-team-race-fowle',), Date:2017-04-08 00:00:00
# Currently analyzing race 8000/55065 in ('s17/sperry-women-west-semis',), Date:2017-05-23 00:00:00
# Currently analyzing race 9000/55065 in ('f17/owlapalooza-2017',), Date:2017-09-30 00:00:00
# Currently analyzing race 10000/55065 in ('f17/nickerson-2017',), Date:2017-10-28 00:00:00
# Currently analyzing race 11000/55065 in ('s18/bob-bavier-team-race',), Date:2018-03-03 00:00:00
# Currently analyzing race 12000/55065 in ('s18/central',), Date:2018-03-24 00:00:00
# Currently analyzing race 13000/55065 in ('s18/sam-reul',), Date:2018-04-07 00:00:00
# Currently analyzing race 14000/55065 in ('s18/america',), Date:2018-04-28 00:00:00
# Currently analyzing race 15000/55065 in ('f18/top-coed',), Date:2018-09-22 00:00:00
# Currently analyzing race 16000/55065 in ('f18/mcgill-cup',), Date:2018-10-13 00:00:00
# Currently analyzing race 17000/55065 in ('s19/mcintyre-team-race',), Date:2019-02-23 00:00:00
# Currently analyzing race 18000/55065 in ('s19/graham-hall',), Date:2019-03-16 00:00:00
# Currently analyzing race 19000/55065 in ('s19/team-race-challenge',), Date:2019-03-30 00:00:00
# Currently analyzing race 20000/55065 in ('s19/central-series-four',), Date:2019-04-14 00:00:00
# Currently analyzing race 21000/55065 in ('f19/mt-hope-invite',), Date:2019-09-07 00:00:00
# Currently analyzing race 22000/55065 in ('f19/pere-marquette',), Date:2019-10-05 00:00:00
# Currently analyzing race 23000/55065 in ('f19/fall-pacific-coast-champs-jv',), Date:2019-11-16 00:00:00
# Currently analyzing race 24000/55065 in ('s20/sharpe-team-race',), Date:2020-02-29 00:00:00
# Currently analyzing race 25000/55065 in ('s21/robin-wallace-team-race',), Date:2021-03-27 00:00:00
# Currently analyzing race 26000/55065 in ('f21/chesapeake-invitational',), Date:2021-09-18 00:00:00
# Currently analyzing race 27000/55065 in ('f21/david-lee-arnoff',), Date:2021-10-16 00:00:00
# Currently analyzing race 28000/55065 in ('f21/fall-pacific-coast',), Date:2021-11-13 00:00:00
# Currently analyzing race 29000/55065 in ('s22/hap-moore',), Date:2022-03-05 00:00:00
# Currently analyzing race 30000/55065 in ('s22/seahawk-women-team-race-interconference',), Date:2022-03-26 00:00:00
# Currently analyzing race 31000/55065 in ('s22/yale-tr-connecticut',), Date:2022-04-02 00:00:00
# Currently analyzing race 32000/55065 in ('s22/sailpack-oriental-intercollegiate',), Date:2022-04-23 00:00:00
# Currently analyzing race 33000/55065 in ('f22/battle-lake-erie',), Date:2022-09-17 00:00:00
# Currently analyzing race 34000/55065 in ('f22/stoney-burke-jv',), Date:2022-10-08 00:00:00
# Currently analyzing race 35000/55065 in ('s23/q1-reagatta',), Date:2023-02-04 00:00:00
# Currently analyzing race 36000/55065 in ('s23/john-jackson-team-race',), Date:2023-03-11 00:00:00
# Currently analyzing race 37000/55065 in ('s23/jan-friis-team-race',), Date:2023-03-25 00:00:00
# Currently analyzing race 38000/55065 in ('s23/mystic-lake-team-racing-invite',), Date:2023-04-08 00:00:00
# Currently analyzing race 39000/55065 in ('s23/women-team-race-national',), Date:2023-04-29 00:00:00
# Currently analyzing race 40000/55065 in ('f23/moody',), Date:2023-09-30 00:00:00
# Currently analyzing race 41000/55065 in ('f23/wisco-womens',), Date:2023-10-21 00:00:00
# Currently analyzing race 42000/55065 in ('s24/usf-women-team-race',), Date:2024-02-24 00:00:00
# Currently analyzing race 43000/55065 in ('s24/st-mary-women-inter-conference',), Date:2024-03-16 00:00:00
# Currently analyzing race 44000/55065 in ('s24/41st-cardinal-red-lynne-marchiando',), Date:2024-03-30 00:00:00
# Currently analyzing race 45000/55065 in ('s24/mystic-lake-team-race',), Date:2024-04-06 00:00:00
# Currently analyzing race 46000/55065 in ('s24/icsa-open-team-racing-national',), Date:2024-04-25 00:00:00
# Currently analyzing race 47000/55065 in ('f24/maisa-top-women',), Date:2024-09-21 00:00:00
# Currently analyzing race 48000/55065 in ('f24/washington-fall-open',), Date:2024-10-12 00:00:00
# Currently analyzing race 49000/55065 in ('s25/lake-virginia-team-race',), Date:2025-02-15 00:00:00
# Currently analyzing race 50000/55065 in ('s25/bud-morrow-cup',), Date:2025-03-15 00:00:00
# Currently analyzing race 51000/55065 in ('s25/invite',), Date:2025-03-29 00:00:00
# Currently analyzing race 52000/55065 in ('s25/laker-showdown',), Date:2025-04-12 00:00:00
# Currently analyzing race 53000/55065 in ('s25/icsa-women-team-race-national',), Date:2025-04-27 00:00:00
# Currently analyzing race 54000/55065 in ('f25/troy-swetnam-2025',), Date:2025-09-27 00:00:00
# Currently analyzing race 55000/55065 in ('f25/kiara-broudy',), Date:2025-11-01 00:00:00
# Calculations finished.
# Outputting to files

# %%
import mysql.connector
import os
from dotenv import load_dotenv
load_dotenv()

connection = mysql.connector.connect(
        host=os.getenv('DB_HOST'),
        port=os.getenv('DB_PORT'),
        user=os.getenv('DB_USER'),
        password=os.getenv('DB_PASS'),
        database=os.getenv('DB_NAME')
    )
cursor = connection.cursor()

# %%
import Teams
importlib.reload(Teams)
from Teams import uploadTeams
from config import Config

uploadTeams(people, cursor, connection, Config())
# Out:
# inserted team Hawaii
# inserted team Brown
# inserted team Southern Cal
# inserted team Salve Regina
# inserted team UC Santa Barbara
# inserted team Cal Poly
# inserted team Washington
# inserted team Channel Islands
# inserted team UC San Diego
# inserted team British Columbia
# inserted team UC Los Angeles
# inserted team Westmont College
# inserted team Arizona State
# inserted team Texas A&M Galveston
# inserted team Texas A&M
# inserted team Tulane
# inserted team Rice
# inserted team Texas
# inserted team Oklahoma State
# inserted team Texas A&M C. Christ
# inserted team Central Oklahoma
# inserted team Notre Dame
# inserted team Jacksonville
# inserted team Florida
# inserted team Tennessee
# inserted team Rollins
# inserted team North Carolina State
# inserted team Georgia Tech
# inserted team Auburn
# inserted team Charleston
# inserted team South Florida
# inserted team Old Dominion
# inserted team Eckerd
# inserted team Florida State
# inserted team U. Miami
# inserted team UW Milwaukee
# inserted team Stony Brook
# inserted team Duke
# inserted team Clemson
# inserted team U South Carolina
# inserted team UNC Wilmington
# inserted team Georgia
# inserted team Berkeley
# inserted team CSU Long Beach
# inserted team Monterey Bay
# inserted team UC Irvine
# inserted team UC Davis
# inserted team Rhode Island
# inserted team Georgetown
# inserted team Dartmouth
# inserted team MIT
# inserted team George Washington
# inserted team Navy
# inserted team Fordham
# inserted team Northeastern
# inserted team Christopher Newport
# inserted team Victoria
# inserted team Boston University
# inserted team Miami University
# inserted team Hampton
# inserted team Virginia
# inserted team Stevens
# inserted team Columbia
# inserted team NY Maritime
# inserted team Kings Point
# inserted team St. Mary's
# inserted team Maryland
# inserted team Virginia Tech
# inserted team Drexel
# inserted team Maryland/Baltimore
# inserted team Buffalo
# inserted team UC Santa Cruz
# inserted team Santa Clara
# inserted team Wisconsin
# inserted team Michigan
# inserted team Washington College
# inserted team Minnesota
# inserted team Yale
# inserted team Hobart & William
# inserted team Vermont
# inserted team Connecticut College
# inserted team Harvard
# inserted team Roger Williams
# inserted team Syracuse
# inserted team Tufts
# inserted team Middlebury
# inserted team New College
# inserted team William and Mary
# inserted team Gannon
# inserted team Boston College
# inserted team Stanford
# inserted team Bowdoin
# inserted team Lewis & Clark
# inserted team Monmouth
# inserted team American
# inserted team Michigan State
# inserted team Hope
# inserted team Western Michigan
# inserted team Toledo
# inserted team Ohio State
# inserted team Mass Maritime
# inserted team Coast Guard
# inserted team Bates
# inserted team Fairfield
# inserted team Sacred Heart
# inserted team Wentworth Institute
# inserted team Providence
# inserted team Iowa State
# inserted team Iowa
# inserted team Indiana
# inserted team Davidson
# inserted team Oregon State
# inserted team Western Washington
# inserted team U. Rochester
# inserted team Army
# inserted team New Hampshire
# inserted team U. Connecticut
# inserted team UMass Dartmouth
# inserted team Wesleyan
# inserted team U. Mass/ Amherst
# inserted team U New England
# inserted team Denison
# inserted team Northern Michigan
# inserted team Ohio
# inserted team Pennsylvania
# inserted team Villanova
# inserted team Maine Maritime
# inserted team Michigan Tech
# inserted team Illinois
# inserted team Chicago
# inserted team Northwestern
# inserted team Grand Valley State
# inserted team Washington U
# inserted team Marquette
# inserted team Lake Forest
# inserted team Cornell
# inserted team Oregon
# inserted team Portland State
# inserted team Princeton
# inserted team Queen's
# inserted team Penn State
# inserted team Ocean County
# inserted team Delaware
# inserted team Rutgers
# inserted team Worcester Polytech
# inserted team Emmanuel College
# inserted team St. John's
# inserted team U Pittsburgh
# inserted team Webb Institute
# inserted team McGill
# inserted team Citadel
# inserted team Colgate
# inserted team Catholic U America
# inserted team Loyola College
# inserted team Ottawa
# inserted team Royal Military
# inserted team Dalhousie
# inserted team U Toronto
# inserted team New Orleans
# inserted team Kansas
# inserted team Bentley
# inserted team Brandeis
# inserted team Cal Maritime
# inserted team San Diego State
# inserted team Loyola
# inserted team North Texas
# inserted team Vanderbilt
# inserted team Purdue
# inserted team North Carolina
# inserted team Hillsdale
# inserted team Amherst
# inserted team Williams
# inserted team Hamilton
# inserted team Rochester
# inserted team Wellesley
# inserted team Hosei Univerisity
# inserted team Colorado
# inserted team John Carroll
# inserted team U.  Mass/ Boston
# inserted team Mercyhurst
# inserted team Penn State Behrend
# inserted team Indiana U Pennsylvan
# inserted team U Nebraska
# inserted team U Maine
# inserted team Texas Christian
# inserted team Embry-Riddle
# inserted team Palm Beach Atlantic
# inserted team U of Central Florida
# inserted team Baldwin-Wallace
# inserted team Saint Mary's College
# inserted team Olin
# inserted team Baylor
# inserted team Texas Tech
# inserted team Wake Forest
# inserted team Georgia Southern
# inserted team East Carolina
# inserted team Florida Tech
# inserted team Saint Thomas
# inserted team Cincinnati
# inserted team Florida Gulf Coast
# inserted team Saginaw Valley
# inserted team Coastal Georgia
# inserted team Cleveland State
# inserted team Sewanee
# inserted team Case Western
# inserted team Oklahoma
# inserted team Gonzaga
# inserted team Salisbury
# inserted team Santa Barbara City
# inserted team Johnson and Wales
# inserted team Fenway
# inserted team Illinois (Chicago)
# inserted team Lawrence
# inserted team Puget Sound
# inserted team College Sailing
# inserted team Landing School
# inserted team North Florida
# inserted team Cal Poly Maritime
# inserted team Florida Int
# inserted team Ole Miss

# %%
# print(people['carter-anderson'].races)
# [r for r in people['carter-anderson'].races if r['type'] == 'team']
people['carter-anderson'].seasons
# Out:
# {'skipper': [('f23', 'UC Santa Cruz'),
#   ('s24', 'UC Santa Cruz'),
#   ('f24', 'Northeastern'),
#   ('s25', 'Northeastern'),
#   ('f25', 'Northeastern')],
#  'crew': [('f23', 'UC Santa Cruz'), ('s24', 'UC Santa Cruz')]}

# %%
cursor.close()
connection.close()

# %%
[] 
[] 
[{'name': 'Grant Smith', 'key': 'grant-smith-2028', 'mu': 20.52080443977176, 'sigma': 7.808189191908399}]
[] 

[{'name': 'Emma Cole', 'key': 'emma-cole', 'mu': 48.355690372583496, 'sigma': 3.1259768612375303}] 
[{'name': 'Emma Cole', 'key': 'emma-cole', 'mu': 23.89681897384292, 'sigma': 5.818143889252487}] 
[{'name': 'Charles Wilkinson', 'key': 'charles-wilkinson', 'mu': 26.302455501274046, 'sigma': 7.653003730415235}, {'name': 'Matthew Chen', 'key': 'matthew-chen', 'mu': 23.065777163640416, 'sigma': 7.5333777643145705}, {'name': 'Carter Anderson', 'key': 'carter-anderson', 'mu': 17.666279675283626, 'sigma': 6.985080294168721}] 
[]

# %%
# [r for r in people['carter-anderson'].races if r['type'] == 'team']
people['carter-anderson'].seasons
# Out:
# {'skipper': [('f23', 'UC Santa Cruz'),
#   ('s24', 'UC Santa Cruz'),
#   ('f24', 'Northeastern'),
#   ('s25', 'Northeastern'),
#   ('f25', 'Northeastern')],
#  'crew': [('f23', 'UC Santa Cruz'), ('s24', 'UC Santa Cruz')]}

# %%
df_races_full
