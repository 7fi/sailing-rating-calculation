# %%
import importlib
import main

people = main.main()
# Out:
# Reading from files.
# Setup complete.
# Starting calculations.
# Currently analyzing race 1000/32496 in ('s16/mosbacher-owen-knapp-trophies',), Date:2016-04-16 00:00:00
# Currently analyzing race 2000/32496 in ('f16/toni-deutsch',), Date:2016-09-10 00:00:00
# Currently analyzing race 3000/32496 in ('f16/south-series',), Date:2016-10-08 00:00:00
# Currently analyzing race 4000/32496 in ('s17/saisa-women',), Date:2017-03-25 00:00:00
# Currently analyzing race 5000/32496 in ('s17/america-maisa-conference',), Date:2017-04-29 00:00:00
# Currently analyzing race 6000/32496 in ('f17/philly-fleet-race',), Date:2017-09-30 00:00:00
# Currently analyzing race 7000/32496 in ('f17/nickerson-2017',), Date:2017-10-28 00:00:00
# Currently analyzing race 8000/32496 in ('s18/seisa-dinghy',), Date:2018-04-07 00:00:00
# Currently analyzing race 9000/32496 in ('f18/fall-fury',), Date:2018-09-08 00:00:00
# Currently analyzing race 10000/32496 in ('f18/u-of-i',), Date:2018-10-06 00:00:00
# Currently analyzing race 11000/32496 in ('f18/triangle-tango',), Date:2018-11-10 00:00:00
# Currently analyzing race 12000/32496 in ('s19/navy-spring',), Date:2019-04-13 00:00:00
# Currently analyzing race 13000/32496 in ('f19/harvard-invitational',), Date:2019-09-08 00:00:00
# Currently analyzing race 14000/32496 in ('f19/rollins-golden-bailer-developmental',), Date:2019-10-05 00:00:00
# Currently analyzing race 15000/32496 in ('s20/old-florida',), Date:2020-02-08 00:00:00
# Currently analyzing race 16000/32496 in ('f21/kingsmill-cup',), Date:2021-09-18 00:00:00
# Currently analyzing race 17000/32496 in ('f21/oyster-bowl-spat',), Date:2021-10-09 00:00:00
# Currently analyzing race 18000/32496 in ('s22/jeff-simon-women',), Date:2022-01-29 00:00:00
# Currently analyzing race 19000/32496 in ('s22/84th-boston-dinghy-club-challenge-cup',), Date:2022-04-23 00:00:00
# Currently analyzing race 20000/32496 in ('f22/webb-wollum',), Date:2022-09-24 00:00:00
# Currently analyzing race 21000/32496 in ('f22/savin-hill-invite',), Date:2022-10-15 00:00:00
# Currently analyzing race 22000/32496 in ('s23/stony-brook-cup',), Date:2023-03-25 00:00:00
# Currently analyzing race 23000/32496 in ('s23/nu-spring',), Date:2023-05-06 00:00:00
# Currently analyzing race 24000/32496 in ('f23/open-atlantic-coast-championships-round-1a',), Date:2023-10-07 00:00:00
# Currently analyzing race 25000/32496 in ('f23/maisa-women-fall-dinghy',), Date:2023-10-28 00:00:00
# Currently analyzing race 26000/32496 in ('s24/wick-womens-event',), Date:2024-04-06 00:00:00
# Currently analyzing race 27000/32496 in ('f24/women-kp-invite',), Date:2024-09-07 00:00:00
# Currently analyzing race 28000/32496 in ('f24/stu-nelson-connecticut',), Date:2024-10-05 00:00:00
# Currently analyzing race 29000/32496 in ('f24/cedarfest',), Date:2024-10-26 00:00:00
# Currently analyzing race 30000/32496 in ('s25/oberg',), Date:2025-04-12 00:00:00
# Currently analyzing race 31000/32496 in ('f25/allstate-sugar-bowl-women',), Date:2025-09-20 00:00:00
# Currently analyzing race 32000/32496 in ('f25/lake-virginia-invitational',), Date:2025-10-18 00:00:00
# Calculations finished.
# Outputting to files

# %%
import mysql.connector
import os
from dotenv import load_dotenv
load_dotenv()

connection = mysql.connector.connect(
        host=os.getenv('DB_HOST'),
        port=os.getenv('DB_PORT'),
        user=os.getenv('DB_USER'),
        password=os.getenv('DB_PASS'),
        database=os.getenv('DB_NAME')
    )
cursor = connection.cursor()

# %%
import Teams
importlib.reload(Teams)
from Teams import uploadTeams
from config import Config

uploadTeams(people,cursor, connection, Config())
# Out:
# [] [] [] [] [{'name': 'Carter Anderson', 'key': 'carter-anderson', 'mu': 42.78735670454051, 'sigma': 7.093254354048607}, {'name': 'Isabella Cho', 'key': 'isabella-cho', 'mu': 23.233950303499274, 'sigma': 6.754354992630952}, {'name': 'Sylvia Burns', 'key': 'sylvia-burns', 'mu': 23.960490102270033, 'sigma': 8.154438693561884}] [{'name': 'Sylvia Burns', 'key': 'sylvia-burns', 'mu': 17.64522366816221, 'sigma': 7.19780003268256}] [] []
# Northeastern 595.9026119583419 150.87396094712477 0.0 0.0 1438.9385500736469 0.0

# %%
cursor.close()
connection.close()

# %%
[{'name': 'Caeden Nodurft', 'key': 'caeden-nodurft', 'mu': 25.0, 'sigma': 8.333333333333334}, {'name': 'Carter Anderson', 'key': 'carter-anderson', 'mu': 25.0, 'sigma': 8.333333333333334}, {'name': 'Charles Wilkinson', 'key': 'charles-wilkinson', 'mu': 25.0, 'sigma': 8.333333333333334}] 

[{'name': 'Caeden Nodurft', 'key': 'caeden-nodurft', 'mu': 25.0, 'sigma': 8.333333333333334}, {'name': 'Carter Anderson', 'key': 'carter-anderson', 'mu': 25.0, 'sigma': 8.333333333333334}] 

[{'name': 'Carter Anderson', 'key': 'carter-anderson', 'mu': 42.78735670454051, 'sigma': 7.093254354048607}, {'name': 'Lydia Frost', 'key': 'lydia-frost', 'mu': 32.09282320249342, 'sigma': 7.954814374868476}, {'name': 'Jack Whitman', 'key': 'jack-whitman', 'mu': 29.48102217540104, 'sigma': 7.946272875509723}] 

[{'name': 'Caeden Nodurft', 'key': 'caeden-nodurft', 'mu': 25.0, 'sigma': 8.333333333333334}, {'name': 'Carter Anderson', 'key': 'carter-anderson', 'mu': 25.0, 'sigma': 8.333333333333334}] [{'name': 'Caeden Nodurft', 'key': 'caeden-nodurft', 'mu': 25.0, 'sigma': 8.333333333333334}, {'name': 'Carter Anderson', 'key': 'carter-anderson', 'mu': 25.0, 'sigma': 8.333333333333334}, {'name': 'Charles Wilkinson', 'key': 'charles-wilkinson', 'mu': 25.0, 'sigma': 8.333333333333334}] [{'name': 'Caeden Nodurft', 'key': 'caeden-nodurft', 'mu': 25.0, 'sigma': 8.333333333333334}, {'name': 'Carter Anderson', 'key': 'carter-anderson', 'mu': 25.0, 'sigma': 8.333333333333334}]

# %%
people['carter-anderson'].hasTargetSeasons(Config().targetSeasons, 'skipper')
# Out:
# True
